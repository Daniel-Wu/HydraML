# %%
!~/.local/bin/gshell
# Out:
# Usage: gshell [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   -V, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   about     show account status
#   cd        change directory
#   download  download file
#   info      show file information
#   init      initialize gshell
#   ll        list files in detail
#   ls        list files
#   mkdir     make directory
#   open      open current site on browser
#   pwd       print current working directory
#   rm        remove file
#   share     share file
#   switch    switch user
#   upload    upload file

# %%
!~/.local/bin/gshell cd /CORAL\ !!!
!~/.local/bin/gshell ll
# Out:
# /home/dwubusiness2/.local/lib/python3.5/site-packages/gshell/__init__.py:100: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(open(CONFIG_FILE))
# /home/dwubusiness2/.local/lib/python3.5/site-packages/gshell/__init__.py:62: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(open(CONFIG_FILE))
# /home/dwubusiness2/.local/lib/python3.5/site-packages/gshell/__init__.py:100: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(open(CONFIG_FILE))
# ...

# %%
import os
os.chdir("/home")
os.listdir()
# Out:
# ['dwubusiness2',
#  'CleanData',
#  'shreyaravi',
#  'jupyter',
#  'HydraML',
#  'dwubusiness',
#  'photos',
#  'HydraML_Daniel',
#  'sravi2',
#  '.ipynb_checkpoints',
#  'annelee',
#  'dwubu',
#  'alee7368',
#  'dataset',
#  'daniel']

# %%
!~/.local/bin/gshell download -r Our\ data
# Out:
# /home/dwubusiness2/.local/lib/python3.5/site-packages/gshell/__init__.py:100: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(open(CONFIG_FILE))
# /home/dwubusiness2/.local/lib/python3.5/site-packages/gshell/__init__.py:62: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(open(CONFIG_FILE))
# ...

# %%
!~/.local/bin/gshell -h
# Out:
# Usage: gshell [OPTIONS] COMMAND [ARGS]...
#
# Options:
#   -V, --version  Show the version and exit.
#   -h, --help     Show this message and exit.
#
# Commands:
#   about     show account status
#   cd        change directory
#   download  download file
#   info      show file information
#   init      initialize gshell
#   ll        list files in detail
#   ls        list files
#   mkdir     make directory
#   open      open current site on browser
#   pwd       print current working directory
#   rm        remove file
#   share     share file
#   switch    switch user
#   upload    upload file
