# %% [markdown]
# # Reformat VIA Annotations for retinanet

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed May  8 15:38:09 2019

Convenience script that converts all bounding polygons to minimum rectangular bounding boxes in a VIA file, and then outputs a csv format which aligns with dataloader

VIA Image format: We convert
{"name":"polygon","all_points_x":[22,13,256,289,271,22],"all_points_y":[881,921,1045,1025,983,881]}
to
{"name":"rect","x":710,"y":405,"width":78,"height":137}

@author: Daniel Wu
"""

import sys
import pandas as pd
import json
import os
import numpy as np

print('Warning: the current version of this script ignores class ids, and just assigns all to class 1')
# Out:
# Warning: the current version of this script ignores class ids, and just assigns all to class 1

# %%
#Treats first command line option as filepath, unless unspecified
def reformat_via(filepath, outpath):
    
    labels = pd.read_csv(filepath)
    base_dir = os.path.abspath(os.path.dirname(filepath))

    img_names = []
    class_ids = []
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []

    #Go through row by row
    for i in range(labels.shape[0]):

        box = json.loads(labels.iloc[i].region_shape_attributes)

        #Skip empty boxes
        if "name" not in box.keys():
            continue

        if box["name"] == "polygon":
            max_x = max(box['all_points_x'])
            min_x = min(box['all_points_x'])
            max_y = max(box['all_points_y'])
            min_y = min(box['all_points_y'])

            box = {"name":"rect","x":min_x,"y":min_y,"width":max_x - min_x,"height":max_y - min_y}

        xmins.append(box['x'])
        ymins.append(box['y'])
        xmaxs.append(box['x'] + box['width'])
        ymaxs.append(box['y'] + box['height'])

        img_names.append(os.path.join(base_dir, labels.iloc[i]['#filename']))
        class_ids.append('sperm')

    print(f'There were {len(img_names)} total annotations.')
    annots = np.vstack((img_names, xmins, ymins, xmaxs, ymaxs, class_ids)).T
    new_labels = pd.DataFrame(annots, columns = ['image_name', 'xmin', 'ymin', 'xmax', 'ymax',  'class_id'])

    #Save and export
    outpath = os.path.join(os.path.dirname(filepath), outpath)
    new_labels.to_csv(outpath, index=False, header=False)

# %%
reformat_via('datasets/TESE_retinanet/via_regions_all.csv', 'annot_all.csv')
reformat_via('datasets/TESE_retinanet/via_regions_train.csv', 'annot_train.csv')
reformat_via('datasets/TESE_retinanet/via_regions_val.csv', 'annot_val.csv')
reformat_via('datasets/TESE_retinanet/via_regions_test.csv', 'annot_test.csv')
# Out:
# There were 1377 total annotations.
# There were 1094 total annotations.
# There were 141 total annotations.
# There were 142 total annotations.

# %%
df = pd.read_csv('datasets/TESE_retinanet/annot_all.csv')
df
# Out:
#      /home/users/danjwu/sperm/datasets/TESE_retinanet/01172018-OC-TESE_597.jpg  \
# 0     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 2     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 3     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 4     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 5     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 6     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 7     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 8     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 9     /home/users/danjwu/sperm/datasets/TESE_retinan...
# 10    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 11    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 12    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 13    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 14    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 15    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 16    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 17    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 18    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 19    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 20    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 21    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 22    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 23    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 24    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 25    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 26    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 27    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 28    /home/users/danjwu/sperm/datasets/TESE_retinan...
# 29    /home/users/danjwu/sperm/datasets/TESE_retinan...
# ...                                                 ...
# 1346  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1347  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1348  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1349  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1350  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1351  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1352  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1353  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1354  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1355  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1356  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1357  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1358  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1359  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1360  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1361  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1362  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1363  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1364  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1365  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1366  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1367  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1368  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1369  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1370  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1371  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1372  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1373  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1374  /home/users/danjwu/sperm/datasets/TESE_retinan...
# 1375  /home/users/danjwu/sperm/datasets/TESE_retinan...
#
#        355  152   425   295  sperm
# 0        3  329   116   404  sperm
# 1      237  165   384   221  sperm
# 2      245  255   334   324  sperm
# 3      404  244   478   337  sperm
# 4      230  130   339   193  sperm
# 5      404  238   504   281  sperm
# 6      395  277   529   322  sperm
# 7       46  336   128   391  sperm
# 8      273  202   377   254  sperm
# 9      547  353   621   403  sperm
# 10     265   49   379   109  sperm
# 11     282  362   384   423  sperm
# 12     264  147   368   207  sperm
# 13     270  180   387   289  sperm
# 14     229  275   343   333  sperm
# 15     269  177   331   272  sperm
# 16     411  425   535   478  sperm
# 17     279  159   384   218  sperm
# 18      97  411   224   477  sperm
# 19     268  284   387   331  sperm
# 20     294  195   393   240  sperm
# 21     267   56   342   123  sperm
# 22     327  140   428   219  sperm
# 23     241  165   398   201  sperm
# 24     432   63   595   136  sperm
# 25     312  257   396   325  sperm
# 26     308  204   420   293  sperm
# 27     358  211   466   272  sperm
# 28     364  223   478   260  sperm
# 29     328  157   440   229  sperm
# ...    ...  ...   ...   ...    ...
# 1346   754  374   889   480  sperm
# 1347  1110   48  1285   204  sperm
# 1348  1258  297  1402   491  sperm
# 1349  1046  557  1190   705  sperm
# 1350   492  784   712  1040  sperm
# 1351    76   26   266   176  sperm
# 1352   744  324   916   474  sperm
# 1353   653  472   863   645  sperm
# 1354  1378   19  1549   155  sperm
# 1355   980  180  1240   313  sperm
# 1356   370  223   710   349  sperm
# 1357   408  738   701   917  sperm
# 1358   787  569   985   677  sperm
# 1359  1103    0  1371    81  sperm
# 1360   968  308  1107   491  sperm
# 1361   760  395   872   664  sperm
# 1362   489  313   663   526  sperm
# 1363   890  857  1043   971  sperm
# 1364    61  176   208   336  sperm
# 1365   582  396   717   557  sperm
# 1366   843  435   981   600  sperm
# 1367  1020  102  1133   333  sperm
# 1368  1107  190  1171   500  sperm
# 1369  1186  244  1325   466  sperm
# 1370    45  308   231   441  sperm
# 1371   304  244   564   380  sperm
# 1372   573  221   680   403  sperm
# 1373   779  605   916   747  sperm
# 1374   879  708  1008   854  sperm
# 1375  1240   88  1378   234  sperm
#
# [1376 rows x 6 columns]

# %%
#Remember to write class annotations map
